# %%
import numpy as np

# Importing standard Qiskit libraries
from qiskit import QuantumCircuit, transpile, Aer, IBMQ, execute
from qiskit.tools.jupyter import *
from qiskit.visualization import *
from ibm_quantum_widgets import *
from qiskit.providers.aer import QasmSimulator

# Loading your IBM Quantum account(s)
provider = IBMQ.load_account()
# Out:
# ibmqfactory.load_account:WARNING:2022-06-28 06:40:01,013: Credentials are already in use. The existing account in the session will be replaced.

# %%
q = QuantumRegister(6, 'q')
c = ClassicalRegister(3, 'c')
c_qftadder = QuantumCircuit(q, c)

c_qftadder.h(q[3])
c_qftadder.cp(np.pi / 2, q[4], q[3])
c_qftadder.cp(np.pi / 4, q[5], q[3])
c_qftadder.h(q[4])
c_qftadder.cp(np.pi / 2, q[5], q[4])
c_qftadder.h(q[5])

c_qftadder.h(q[5])
c_qftadder.cx(q[0], q[5])
c_qftadder.cx(q[1], q[5])
c_qftadder.cx(q[2], q[5])
c_qftadder.h(q[5])
c_qftadder.h(q[4])
c_qftadder.cx(q[1], q[4])
c_qftadder.cx(q[2], q[4])
c_qftadder.h(q[4])
c_qftadder.h(q[3])
c_qftadder.cx(q[2], q[3])
c_qftadder.h(q[3])
c_qftadder.h(q[2])

c_qftadder.barrier(q[3],q[4],q[5])
c_qftadder.h(q[3])
c_qftadder.h(q[4])
c_qftadder.h(q[5])
c_qftadder.barrier(q[3],q[4],q[5])
c_qftadder.h(q[3])
c_qftadder.measure(q[3], c[0])


c_qftadder.p(np.pi/2, q[4]).c_if(c, 1)
c_qftadder.h(q[4])
c_qftadder.measure(q[4], c[1])

c_qftadder.p(np.pi/4, q[5]).c_if(c, 1)
c_qftadder.p(np.pi/2, q[5]).c_if(c, 2)
c_qftadder.p(np.pi / 2 + np.pi / 4, q[5]).c_if(c, 3)
c_qftadder.h(q[5])

c_qftadder.measure(q[5], c[2])

# %%
# %matplotlib inline
c_qftadder.draw(output='mpl')

# %%
from qiskit.providers.aer import AerSimulator
from qiskit.visualization import plot_histogram

# %%
from qiskit import IBMQ

provider = IBMQ.get_provider(hub='ibm-q-skku', group='korea-university', project='ku-graduate')
backend = provider.get_backend('ibmq_qasm_simulator')

# %%
job = execute(c_qftadder, backend, shots=100000)
result = job.result()
counts = result.get_counts(c_qftadder)
print("\nTotal count for 00 and 11 are:",counts)
c_qftadder.draw()
# Out:
# Total count for 00 and 11 are: {'000': 12434, '001': 12484, '010': 12561, '011': 12452, '100': 12668, '101': 12503, '110': 12485, '111': 12413}

# %%
from qiskit.transpiler import PassManager
from qiskit.transpiler.passes import Unroller
pass_ = Unroller(['u', 'cx'])
pm = PassManager(pass_)
new_circuit = pm.run(c_qftadder) 
new_circuit.draw(output='mpl')

# %%
new_circuit.count_ops()
# Out:
# OrderedDict([('u', 29), ('cx', 12), ('measure', 3), ('barrier', 2)])
